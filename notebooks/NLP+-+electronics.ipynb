# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

# words = read_data(filename)
# words = read_data('olx_electronics.zip')
words = read_data('electronics_string1500.zip')
print('Data size', len(words))
# Out:
# Data size 205139

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
# vocabulary_size = 50000
vocabulary_size = 10640


def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
print(len(reverse_dictionary))

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 22512], ('and', 5391), ('with', 3761), ('for', 2661), ('to', 2370)]
# Sample data [0, 6, 750, 131, 3, 461, 0, 549, 980, 591] ['UNK', 'new', 'av', 'cable', 'for', 'playstation', 'UNK', 'equipment', '42', 'u']
# 10640

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
# Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 6 new -> 0 UNK
# 6 new -> 750 av
# 750 av -> 6 new
# 750 av -> 131 cable
# 131 cable -> 750 av
# 131 cable -> 3 for
# 3 for -> 461 playstation
# 3 for -> 131 cable

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# Compute the average NCE loss for the batch.
# tf.nce_loss automatically draws a new sample of the negative labels each
# time we evaluate the loss.
    loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

# Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

# Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# Add variable initializer.
    init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001
# num_steps = 10000

with tf.Session(graph=graph) as session:
# We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

# We perform one update step by evaluating the optimizer op (including it
# in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
# The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

# Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  229.089706421
# Nearest to 4: 1080pinbuilt, gamingbrand, n4110, jackwired, agent, durability, whole, 10100,
# Nearest to hp: channelsxbox, any, drops, i3usb, 7000, similar, cealed, managing,
# Nearest to be: d630, wifihp, high, soundhp, numbershigh, port5th, duplicators, x43,
# Nearest to dvd: eee, musiccardreaderdvd, studios, blower, confidential, new2, processorfull, nd,
# Nearest to year: hardisks, subwooferddr3, scart, cheapest, provides, though, forward, loved,
# Nearest to graphics: bulpsi, hddcore, tvcuved, upsthis, domain, detailsslimgame, hdinbuilt, hdd220,
# Nearest to bluetooth: newac, prone, v3, portoriginal, assistant, 156diagonal, flagship, c670,
# Nearest to imenti: twin, is, l305, tshirt, lamps, situations, core2duo, 14b109wm,
# Nearest to as: 28000, town4gb, morebest, hddlenovo, file, tiny, l840, window,
# Nearest to original: bring, electronics, dvb2, antivirusbag, photographic, internetclean, probably, 19ghz,
# Nearest to gb: wd, fmhc10, operates, mugs, 21brand, copierin, ya, believe,
# Nearest to quality: bluetoothbest, newlaptop, gbps, cleanbrand, sdxc, blower, latitude, cracked,
# Nearest to can: 15inch, basketball, pcnew, sand, refreshing, ram20ghz, mega, laptopinbuilt,
# Nearest to our: pcsyou, technology, instantly, ukbrand, portthere, newlg, present500gb, accelerator,
# Nearest to on: detailswashing, backwards, inbuilt, points, rg6brand, 140, newsuperspeed, minutenew,
# Nearest to intel: replaced, inclusive, 12800, wifiricoh, finger, formula, 1510, desktop,
# Average loss at step  2000 :  44.9110163912
# Average loss at step  4000 :  9.27796927643
# Average loss at step  6000 :  5.04237864435
# Average loss at step  8000 :  4.47162059009
# Average loss at step  10000 :  4.22224031782
# Nearest to 4: 3, whole, 1080pinbuilt, dts, kenyabiometric, 10100, UNK, ramwe,
# Nearest to hp: any, inspiron, r4, similar, channelsxbox, apart, drops, 7000,
# Nearest to be: d630, wifihp, bluetoothdvd, ed, console, green, duplicators, soundhp,
# Nearest to dvd: sports, eee, studios, nd, normal, bezel, veriton, bein,
# Nearest to year: scart, hardisks, newhp, ultrathin, cheapest,  , though, provides,
# Nearest to graphics: truevision, hdd220, domain, upsthis, hdinbuilt, bulpsi, bein, hddcore,
# Nearest to bluetooth: portoriginal, c670, cam, prone, 61, normal, v3, flagship,
# Nearest to imenti: bein,  , fire, twin, hse, throw, lamps, core2duo,
# Nearest to as: 28000, decoderbrand, window, adjustable, town4gb, file, callslim, l840,
# Nearest to original: electronics, dvb2, sports, splitter, bring, 6540b, UNK, expand,
# Nearest to gb: wd, sports,  , receptionworks, 4ohm, fmhc10, lockable, 120gb,
# Nearest to quality: sdxc, else, bluetoothbest, education, gbps, cleanbrand, newlaptop, cracked,
# Nearest to can: 15inch, ram20ghz, basketball, portsbrand, laptopinbuilt, protect, he, stabilization,
# Nearest to our: already, instantly, technology, present500gb, copper, ukbrand, hs, portthere,
# Nearest to on: points, newsuperspeed, duplicator, detailswashing, style, 140, for, five,
# Nearest to intel: replaced, 5th,  , l382, 200w, otg, 12800, bein,
# Average loss at step  12000 :  4.05885771406
# Average loss at step  14000 :  3.99889253241
# Average loss at step  16000 :  3.89841562897
# Average loss at step  18000 :  3.86971823025
# Average loss at step  20000 :  3.82753310126
# Nearest to 4: 3, g2technology, 1080pinbuilt, positioned, harddisks, whole, dts, 10chdmi,
# Nearest to hp: inspiron, similar, any, apart, channelsxbox, drops, managing, r4,
# Nearest to be: d630, ed, wifihp, x43, bluetoothdvd, port5th, connect, tunerbluetooth,
# Nearest to dvd: studios, bezel, eee, nd, normal, hardwarebased, smb, b5070,
# Nearest to year: scart, hardisks, ultrathin, newhp, decorders2gb, gateway, damages, cheapest,
# Nearest to graphics: truevision, upsthis, hdd220, domain, reader, bulpsi, hdinbuilt, 80gbram,
# Nearest to bluetooth: cam, portoriginal, normal, v3, 61, prone, disk, nfs,
# Nearest to imenti: hse, bein, fire, dominion,  , lamps, twin, throw,
# Nearest to as: 28000, callslim, decoderbrand, 12500print, l840, adjustable, town4gb, 3750,
# Nearest to original: electronics, dvb2, 6540b, splitter, expand, edge, storejet, antivirusbag,
# Nearest to gb: wd, 4ohm, receptionworks, 120gb,  , fmhc10, lockable, sports,
# Nearest to quality: sdxc, else, education, bluetoothbest, device, product, gbps, cracked,
# Nearest to can: 15inch, ram20ghz, will, basketball, lnb, protect, comfortably, pabx,
# Nearest to our: already, instantly, copper, present500gb, portthere, technology, hs, 15inches,
# Nearest to on: points, newsuperspeed, detailswashing, for, duplicator, intended, arkam, university,
# Nearest to intel: 5th, replaced, morevery, 6910p, negotiablethis, otg, 200w, 2gb500gb,
# Average loss at step  22000 :  3.7256386739
# Average loss at step  24000 :  3.75171883351
# Average loss at step  26000 :  3.69766790289
# Average loss at step  28000 :  3.64589342445
# Average loss at step  30000 :  3.62623171079
# Nearest to 4: 3, g2technology, 1080pinbuilt, positioned, harddisks, 10chdmi, 2, dvdwe,
# Nearest to hp: inspiron, apart, similar, channelsxbox, managing, drops, tier, any,
# Nearest to be: ed, wifihp, d630, x43, connect, tunerbluetooth, port5th, markets,
# Nearest to dvd: bezel, studios, presets, hardwarebased, b5070, eee, hidefinition, nd,
# Nearest to year: scart, yr, ultrathin, hardisks, newhp, months, damages, decorders2gb,
# Nearest to graphics: truevision, reader, domain, upsthis, hdd220, bulpsi, 80gbram, hdinbuilt,
# Nearest to bluetooth: cam, portoriginal, v3, normal, disk, bluetooth®, supermarkets, intense,
# Nearest to imenti: hse, dominion, fire,  , bein, lamps, tomboya, street,
# Nearest to as: 28000, decoderbrand, 12500print, l840, callslim, adjustable, 3750, town4gb,
# Nearest to original: electronics, dvb2, 6540b, rm, storejet, expand, splitter, edge,
# Nearest to gb: 4ohm, wd,  , 120gb, receptionworks, 250gb, 500gb, fmhc10,
# Nearest to quality: sdxc, education, competitive, else, device, product, cracked, bluetoothbest,
# Nearest to can: 15inch, will, ram20ghz, basketball, lnb, pabx, if, 70x8500digital,
# Nearest to our: already, instantly, copper, present500gb, portthere, hs, technology, 15inches,
# Nearest to on: points, newsuperspeed, intended, detailswashing, for, arkam, university, payne,
# Nearest to intel: 5th, replaced, morevery, 6910p, negotiablethis, 2gb500gb, otg, 200w,
# Average loss at step  32000 :  3.57272907925
# Average loss at step  34000 :  3.57975421125
# Average loss at step  36000 :  3.54392854387
# Average loss at step  38000 :  3.48684241003
# Average loss at step  40000 :  3.51995248234
# Nearest to 4: 3, g2technology, 1080pinbuilt, 2, positioned, 16, harddisks, 10chdmi,
# Nearest to hp: apart, inspiron, similar, channelsxbox, exuk, managing, drops, tier,
# Nearest to be: ed, x43, wifihp, d630, connect, markets, tunerbluetooth, deliveryselling,
# Nearest to dvd: bezel, studios, presets, distributors, hardwarebased, sumsung, real, hidefinition,
# Nearest to year: yr, scart, ultrathin, months, newhp, hardisks, damages, a5,
# Nearest to graphics: reader, truevision, domain, upsthis, hdd220, bulpsi, graphic, hdinbuilt,
# Nearest to bluetooth: cam, v3, portoriginal, bluetooth®, mousehp, normal, intense, 35ghz,
# Nearest to imenti: hse, fire, dominion,  , tomboya, lamps, bein, street,
# Nearest to as: 28000, decoderbrand, 12500print, outputs, l840, callslim, 3750, shopsbrand,
# Nearest to original: electronics, dvb2, rm, storejet, 6540b, edge, splitter, new51ch,
# Nearest to gb: 4ohm,  , 120gb, 250gb, receptionworks, wd, tb, 500gb,
# Nearest to quality: sdxc, education, x200s, competitive, tonners, else, bright, cracked,
# Nearest to can: will, 15inch, ram20ghz, basketball, if, pabx, m43brand, lnb,
# Nearest to our: already, instantly, copper, portthere, present500gb, hs, 15inches, entry,
# Nearest to on: newsuperspeed, points, intended, arkam, payne, detailswashing, university, into,
# Nearest to intel: 5th, morevery, 6910p, 2gb500gb, replaced, negotiablethis, i35005u, ready,
# Average loss at step  42000 :  3.47346072578
# Average loss at step  44000 :  3.44674711925
# Average loss at step  46000 :  3.42422194397
# Average loss at step  48000 :  3.39428452462
# Average loss at step  50000 :  3.41483365947
# Nearest to 4: 3, g2technology, 2, 16, positioned, 1080pinbuilt, 10chdmi, 2013just,
# Nearest to hp: apart, inspiron, similar, channelsxbox, exuk, managing, nicely, drops,
# Nearest to be: ed, x43, connect, i55250u, clean1tb, tunerbluetooth, markets, wifihp,
# Nearest to dvd: bezel, distributors, presets, hardwarebased, real, studios, sumsung, transcend,
# Nearest to year: yr, scart, months, ultrathin, newhp, years, a5, hardisks,
# Nearest to graphics: reader, truevision, domain, upsthis, graphic, hdd220, bulpsi, hdinbuilt,
# Nearest to bluetooth: cam, v3, bluetooth®, mousehp, portoriginal, blueray, 35ghz, intense,
# Nearest to imenti: hse, fire, tomboya, dominion,  , lamps, street, nation,
# Nearest to as: 28000, decoderbrand, 12500print, outputs, callslim, 3750, l840, shopsbrand,
# Nearest to original: rm, electronics, storejet, edge, 6540b, dvb2, new51ch, splitter,
# Nearest to gb:  , tb, 4ohm, 250gb, 120gb, 500gb, receptionworks, sdram,
# Nearest to quality: sdxc, x200s, competitive, bright, tonners, education, else, 48r560coriginal,
# Nearest to can: will, 15inch, ram20ghz, basketball, if, m43brand, pabx, lnb,
# Nearest to our: already, instantly, copper, portthere, present500gb, entry, 15inches, hs,
# Nearest to on: newsuperspeed, points, intended, arkam, payne, university, into, detailswashing,
# Nearest to intel: 5th, 2gb500gb, morevery, 6910p, i35005u, negotiablethis, 2ghz, replaced,
# Average loss at step  52000 :  3.37467682481
# Average loss at step  54000 :  3.33350302798
# Average loss at step  56000 :  3.3721540426
# Average loss at step  58000 :  3.32754480046
# Average loss at step  60000 :  3.3218275224
# Nearest to 4: 3, g2technology, 16, 2, positioned, 1080pinbuilt, 2013just, 10chdmi,
# Nearest to hp: apart, similar, channelsxbox, inspiron, nicely, exuk, cover24, drops,
# Nearest to be: ed, x43, i55250u, connect, clean1tb, markets, hse, tunerbluetooth,
# Nearest to dvd: bezel, distributors, real, presets, sumsung, hardwarebased, transcend, studios,
# Nearest to year: yr, months, scart, years, ultrathin, a5, newhp, 15v,
# Nearest to graphics: reader, truevision, domain, graphic, upsthis, bulpsi, hdd220, furniture,
# Nearest to bluetooth: cam, v3, bluetooth®, mousehp, blueray, portoriginal, backlite, 35ghz,
# Nearest to imenti: hse, tomboya, fire, dominion,  , street, lamps, nation,
# Nearest to as: 28000, outputs, decoderbrand, 12500print, 3750, callslim, l840, diskcomes,
# Nearest to original: rm, storejet, electronics, edge, 6540b, new51ch, decoderthe, dvb2,
# Nearest to gb: tb, 4ohm,  , 120gb, watts, wd, tall, receptionworks,
# Nearest to quality: sdxc, bright, x200s, competitive, tonners, education, 48r560coriginal, else,
# Nearest to can: will, if, basketball, ram20ghz, 15inch, m43brand, pabx, 70x8500digital,
# Nearest to our: already, instantly, copper, portthere, present500gb, entry, 15inches, hs,
# Nearest to on: newsuperspeed, points, intended, payne, arkam, university, into, portsamsung,
# Nearest to intel: 5th, 6910p, 2gb500gb, i35005u, 2ghz, morevery, tvintel, 4gb,
# Average loss at step  62000 :  3.29731775749
# Average loss at step  64000 :  3.28117328215
# Average loss at step  66000 :  3.30040930098
# Average loss at step  68000 :  3.26304667741
# Average loss at step  70000 :  3.23257868236
# Nearest to 4: 3, g2technology, 2, 16, 2013just, positioned, 1080pinbuilt, 10chdmi,
# Nearest to hp: apart, channelsxbox, similar, cover24, inspiron, nicely, tier, exuk,
# Nearest to be: x43, connect, ed, i55250u, clean1tb, markets, choose, been,
# Nearest to dvd: distributors, real, bezel, sumsung, transcend, graphicswebcamwifidvd, 14display, warranty,
# Nearest to year: yr, months, scart, years, ultrathin, newhp, a5, 15v,
# Nearest to graphics: reader, truevision, domain, graphic, upsthis, bulpsi, amd, furniture,
# Nearest to bluetooth: cam, mousehp, bluetooth®, v3, blueray, architectural, backlite, 35ghz,
# Nearest to imenti: hse, tomboya, fire, dominion,  , nation, street, lamps,
# Nearest to as: outputs, decoderbrand, 28000, shopsbrand, 12500print, callslim, diskcomes, 3750,
# Nearest to original: storejet, rm, electronics, edge, 6540b, ledfull, spy, new51ch,
# Nearest to gb: tb,  , 4ohm, 120gb, sdram, tall, 250gb, receptionworks,
# Nearest to quality: sdxc, bright, x200s, tonners, competitive, 48r560coriginal, shoporiginal, education,
# Nearest to can: will, if, m43brand, basketball, ram20ghz, pabx, we, 15inch,
# Nearest to our: already, instantly, portthere, copper, present500gb, entry, 15inches, hs,
# Nearest to on: newsuperspeed, points, intended, payne, arkam, university, portsamsung, into,
# Nearest to intel: 5th, 2gb500gb, i35005u, 6910p, 2ghz, tvintel, morevery, 4gb,
# Average loss at step  72000 :  3.2749380368
# Average loss at step  74000 :  3.22548510104
# Average loss at step  76000 :  3.23889166725
# Average loss at step  78000 :  3.19688736439
# Average loss at step  80000 :  3.194903642
# Nearest to 4: 3, g2technology, 16, 2, 2013just, 1080pinbuilt, certifiedbrand, positioned,
# Nearest to hp: apart, channelsxbox, nicely, exuk, cover24, tier, 83, similar,
# Nearest to be: connect, x43, ed, i55250u, choose, been, clean1tb, markets,
# Nearest to dvd: real, distributors, bezel, warranty, warrantyit, 14display, sumsung, graphicswebcamwifidvd,
# Nearest to year: yr, months, years, scart, ultrathin, yrs, a5, week,
# Nearest to graphics: reader, domain, truevision, graphic, upsthis, bulpsi, furniture, amd,
# Nearest to bluetooth: mousehp, cam, v3, bluetooth®, blueray, backlite, architectural, hotspot,
# Nearest to imenti: hse, tomboya, fire, street, dominion, nation,  , located,
# Nearest to as: outputs, decoderbrand, shopsbrand, callslim, diskcomes, 28000, 3750, 12500print,
# Nearest to original: storejet, rm, edge, electronics, 6540b, spy, ledfull, decoderthe,
# Nearest to gb: tb,  , 4ohm, sdram, 120gb, tall, 250gb, digital4gb,
# Nearest to quality: sdxc, bright, tonners, x200s, shoporiginal, competitive, 48r560coriginal, education,
# Nearest to can: will, if, m43brand, basketball, ram20ghz, pabx, we, floorinnovative,
# Nearest to our: already, instantly, portthere, entry, copper, 15inches, present500gb, hs,
# Nearest to on: newsuperspeed, points, intended, payne, arkam, university, portsamsung, into,
# Nearest to intel: 5th, 2gb500gb, i35005u, 6910p, 2ghz, tvintel, resolutionfull, morevery,
# Average loss at step  82000 :  3.21793372905
# Average loss at step  84000 :  3.18765885389
# Average loss at step  86000 :  3.14700545588
# Average loss at step  88000 :  3.20204378688
# Average loss at step  90000 :  3.15174022824
# Nearest to 4: 3, g2technology, 16, 2, 2013just, cruzer, certifiedbrand, 1080pinbuilt,
# Nearest to hp: apart, nicely, channelsxbox, 83, exuk, cover24, monitorbrand, tier,
# Nearest to be: x43, i55250u, choose, connect, been, ed, 30pin, clean1tb,
# Nearest to dvd: real, warranty, distributors, sumsung, bezel, warrantyit, 14display, graphicswebcamwifidvd,
# Nearest to year: yr, years, months, scart, ultrathin, week, yrs, a5,
# Nearest to graphics: reader, domain, truevision, graphic, furniture, upsthis, bulpsi, amd,
# Nearest to bluetooth: mousehp, bluetooth®, cam, v3, architectural, backlite, hotspot, blueray,
# Nearest to imenti: hse, tomboya, fire, street, dominion, nation, located,  ,
# Nearest to as: outputs, decoderbrand, diskcomes, 3750, 28000, 12500print, callslim, shopsbrand,
# Nearest to original: storejet, rm, edge, arrival, electronics, ledfull, spy, 6540b,
# Nearest to gb: tb,  , 4ohm, sdram, 120gb, tall, 250gb, terabytes,
# Nearest to quality: sdxc, shoporiginal, bright, tonners, 48r560coriginal, competitive, terms, x200s,
# Nearest to can: will, if, m43brand, basketball, ram20ghz, pabx, we, floorinnovative,
# Nearest to our: already, instantly, entry, portthere, 15inches, copper, present500gb, hs,
# Nearest to on: newsuperspeed, points, intended, payne, arkam, university, portsamsung, pricesusb,
# Nearest to intel: 2gb500gb, i35005u, 2ghz, 5th, tvintel, 6910p, resolutionfull, nx,
# Average loss at step  92000 :  3.17055109555
# Average loss at step  94000 :  3.1257474395
# Average loss at step  96000 :  3.13358718699
# Average loss at step  98000 :  3.15042900574
# Average loss at step  100000 :  3.1230334819
# Nearest to 4: 3, g2technology, 16, 2, 2013just, cruzer, certifiedbrand, unmatched,
# Nearest to hp: apart, nicely, channelsxbox, 83, monitorbrand, exuk, venues, cardnew,
# Nearest to be: been, choose, x43, i55250u, 30pin, connect, significant, ed,
# Nearest to dvd: real, warranty, warrantyit, 14display, bezel, distributors, sumsung, graphicswebcamwifidvd,
# Nearest to year: yr, years, months, scart, yrs, week, ultrathin, tasks—for,
# Nearest to graphics: reader, truevision, domain, graphic, furniture, upsthis, bulpsi, lans,
# Nearest to bluetooth: mousehp, architectural, hotspot, v3, bluetooth®, backlite, cam, transmitter,
# Nearest to imenti: hse, tomboya, fire, nation, dominion, street, located,  ,
# Nearest to as: outputs, decoderbrand, shopsbrand, diskcomes, 3750, callslim, wks, 12500print,
# Nearest to original: storejet, rm, arrival, ledfull, company, edge, spy, 6540b,
# Nearest to gb: tb,  , sdram, 120gb, 4ohm, 250gb, watts, terabytes,
# Nearest to quality: sdxc, shoporiginal, bright, tonners, definition, terms, competitive, 48r560coriginal,
# Nearest to can: will, if, m43brand, •, we, basketball, floorinnovative, ram20ghz,
# Nearest to our: instantly, already, portthere, entry, 15inches, present500gb, copper, hs,
# Nearest to on: newsuperspeed, points, payne, intended, arkam, portsamsung, university, into,
# Nearest to intel: 2gb500gb, i35005u, 2ghz, tvintel, 6910p, 5th, resolutionfull, nx,

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='electronics.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

    plt.savefig(filename)

try:
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
